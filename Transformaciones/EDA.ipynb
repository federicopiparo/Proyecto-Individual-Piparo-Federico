# %% [markdown]
# # EDA
#
# El Análisis Exploratorio de Datos (Exploratory Data Analysis o EDA) es un paso crucial en el análisis de datos que implica examinar y visualizar un conjunto de datos antes de hacer cualquier modelado o análisis profundo.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_parquet ("C:\\Users\\fede\\Desktop\\LABs 1\\Proyecto individual - Federico Piparo\\Transformaciones\\transformados.parquet")

# %% [markdown]
# ### analisis basicos:

# %%
# Chequeo de nulos
nulos_cantidad = df.isnull().sum()
nulos_porcentaje = (df.isnull().sum() / df.shape[0]) * 100

# Crear un DataFrame con los resultados
nulos_df = pd.DataFrame([nulos_cantidad, nulos_porcentaje], index=['Cantidad de Nulos', 'Porcentaje de Nulos'])
pd.set_option('display.max_columns', None)

# %%
nulos_df
# Out:
#                         nombre_0     nombre_1     nombre_2     nombre_3  \
# Cantidad de Nulos    2354.000000  3683.000000  4593.000000  5725.000000
# Porcentaje de Nulos     5.179204     8.103232    10.105388    12.595982
#
#                         nombre_4      nombre_5     nombre_6      nombre_7  \
# Cantidad de Nulos    8203.000000  10887.000000  13579.00000  16338.000000
# Porcentaje de Nulos    18.048008     23.953268     29.87613     35.946404
#
#                          nombre_8      nombre_9     nombre_10     nombre_11  \
# Cantidad de Nulos    19108.000000  21702.000000  24522.000000  26827.000000
# Porcentaje de Nulos     42.040879     47.748124     53.952608     59.024004
#
#                         nombre_12    nombre_13     nombre_14     nombre_15  \
# Cantidad de Nulos    28893.000000  30707.00000  32296.000000  34754.000000
# Porcentaje de Nulos     63.569558     67.56067     71.056742     76.464764
#
#                         nombre_16     nombre_17     nombre_18     nombre_19  \
# Cantidad de Nulos    36116.000000  37228.000000  38042.000000  38837.000000
# Porcentaje de Nulos     79.461398     81.907989     83.698929     85.448065
#
#                         nombre_20     nombre_21     nombre_22     nombre_23  \
# Cantidad de Nulos    39574.000000  40167.000000  40647.000000  41058.000000
# Porcentaje de Nulos     87.069591     88.374293     89.430376     90.334646
#
#                         nombre_24    nombre_25     nombre_26    nombre_27  \
# Cantidad de Nulos    41416.000000  41722.00000  41998.000000  42247.00000
# Porcentaje de Nulos     91.122308     91.79556     92.402807     92.95065
#
#                         nombre_28     nombre_29     nombre_30     nombre_31  \
# Cantidad de Nulos    42487.000000  42682.000000  42867.000000  43082.000000
# Porcentaje de Nulos     93.478691     93.907725     94.314757     94.787793
#
#                        nombre_32     nombre_33     nombre_34     nombre_35  \
# Cantidad de Nulos    43235.00000  43366.000000  43504.000000  43623.000000
# Porcentaje de Nulos     95.12442     95.412642     95.716266     95.978086
#
#                         nombre_36    nombre_37     nombre_38     nombre_39  \
# Cantidad de Nulos    43729.000000  43820.00000  43918.000000  43988.000000
# Porcentaje de Nulos     96.211304     96.41152     96.627137     96.781149
#
#                         nombre_40     nombre_41     nombre_42     nombre_43  \
# Cantidad de Nulos    44064.000000  44151.000000  44221.000000  44282.000000
# Porcentaje de Nulos     96.948362     97.139777     97.293789     97.427999
#
#                         nombre_44     nombre_45     nombre_46     nombre_47  \
# Cantidad de Nulos    44336.000000  44390.000000  44449.000000  44515.000000
# Porcentaje de Nulos     97.546809     97.665618     97.795428     97.940639
#
#                         nombre_48     nombre_49     nombre_50     nombre_51  \
# Cantidad de Nulos    44560.000000  44610.000000  44650.000000  44707.000000
# Porcentaje de Nulos     98.039647     98.149656     98.237663     98.363072
#
#                         nombre_52     nombre_53     nombre_54     nombre_55  \
# Cantidad de Nulos    44748.000000  44785.000000  44821.000000  44860.000000
# Porcentaje de Nulos     98.453279     98.534686     98.613892     98.699699
#
#                         nombre_56     nombre_57     nombre_58     nombre_59  \
# Cantidad de Nulos    44897.000000  44922.000000  44955.000000  44976.000000
# Porcentaje de Nulos     98.781105     98.836109     98.908715     98.954918
#
#                         nombre_60     nombre_61    nombre_62     nombre_63  \
# Cantidad de Nulos    44998.000000  45018.000000  45041.00000  45056.000000
# Porcentaje de Nulos     99.003322     99.047326     99.09793     99.130932
#
#                         nombre_64     nombre_65     nombre_66     nombre_67  \
# Cantidad de Nulos    45068.000000  45093.000000  45109.000000  45124.000000
# Porcentaje de Nulos     99.157334     99.212339     99.247541     99.280544
#
#                         nombre_68     nombre_69     nombre_70     nombre_71  \
# Cantidad de Nulos    45138.000000  45152.000000  45164.000000  45178.000000
# Porcentaje de Nulos     99.311346     99.342149     99.368551     99.399353
#
#                         nombre_72     nombre_73     nombre_74     nombre_75  \
# Cantidad de Nulos    45189.000000  45204.000000  45215.000000  45227.000000
# Porcentaje de Nulos     99.423555     99.456558     99.480759     99.507162
#
#                         nombre_76     nombre_77     nombre_78     nombre_79  \
# Cantidad de Nulos    45240.000000  45247.000000  45254.000000  45262.000000
# Porcentaje de Nulos     99.535764     99.551165     99.566566     99.584168
#
#                        nombre_80     nombre_81     nombre_82     nombre_83  \
# Cantidad de Nulos    45275.00000  45282.000000  45289.000000  45294.000000
# Porcentaje de Nulos     99.61277     99.628171     99.643572     99.654573
#
#                         nombre_84     nombre_85     nombre_86     nombre_87  \
# Cantidad de Nulos    45302.000000  45309.000000  45312.000000  45320.000000
# Porcentaje de Nulos     99.672174     99.687576     99.694176     99.711778
#
#                         nombre_88     nombre_89     nombre_90     nombre_91  \
# Cantidad de Nulos    45322.000000  45326.000000  45329.000000  45331.000000
# Porcentaje de Nulos     99.716178     99.724979     99.731579     99.735979
#
#                        nombre_92    nombre_93    nombre_94     nombre_95  \
# Cantidad de Nulos    45335.00000  45336.00000  45337.00000  45342.000000
# Porcentaje de Nulos     99.74478     99.74698     99.74918     99.760181
#
#                         nombre_96     nombre_97     nombre_98     nombre_99  \
# Cantidad de Nulos    45346.000000  45348.000000  45353.000000  45356.000000
# Porcentaje de Nulos     99.768982     99.773382     99.784383     99.790984
#
#                        nombre_100    nombre_101    nombre_102    nombre_103  \
# Cantidad de Nulos    45360.000000  45366.000000  45367.000000  45369.000000
# Porcentaje de Nulos     99.799784     99.812985     99.815186     99.819586
#
#                        nombre_104    nombre_105    nombre_106    nombre_107  \
# Cantidad de Nulos    45372.000000  45377.000000  45381.000000  45382.000000
# Porcentaje de Nulos     99.826186     99.837187     99.845988     99.848188
#
#                        nombre_108    nombre_109   nombre_110   nombre_111  \
# Cantidad de Nulos    45385.000000  45386.000000  45390.00000  45391.00000
# Porcentaje de Nulos     99.854789     99.856989     99.86579     99.86799
#
#                       nombre_112   nombre_113    nombre_114    nombre_115  \
# Cantidad de Nulos    45393.00000  45395.00000  45399.000000  45402.000000
# Porcentaje de Nulos     99.87239     99.87679     99.885591     99.892192
#
#                        nombre_116    nombre_117    nombre_118    nombre_119  \
# Cantidad de Nulos    45402.000000  45405.000000  45408.000000  45408.000000
# Porcentaje de Nulos     99.892192     99.898792     99.905393     99.905393
#
#                        nombre_120    nombre_121    nombre_122    nombre_123  \
# Cantidad de Nulos    45409.000000  45411.000000  45413.000000  45414.000000
# Porcentaje de Nulos     99.907593     99.911993     99.916393     99.918594
#
#                        nombre_124    nombre_125    nombre_126    nombre_127  \
# Cantidad de Nulos    45415.000000  45417.000000  45417.000000  45417.000000
# Porcentaje de Nulos     99.920794     99.925194     99.925194     99.925194
#
#                        nombre_128    nombre_129    nombre_130    nombre_131  \
# Cantidad de Nulos    45420.000000  45420.000000  45421.000000  45422.000000
# Porcentaje de Nulos     99.931795     99.931795     99.933995     99.936195
#
#                        nombre_132    nombre_133    nombre_134    nombre_135  \
# Cantidad de Nulos    45422.000000  45423.000000  45424.000000  45424.000000
# Porcentaje de Nulos     99.936195     99.938395     99.940595     99.940595
#
#                        nombre_136    nombre_137    nombre_138    nombre_139  \
# Cantidad de Nulos    45425.000000  45427.000000  45427.000000  45427.000000
# Porcentaje de Nulos     99.942796     99.947196     99.947196     99.947196
#
#                        nombre_140    nombre_141    nombre_142    nombre_143  \
# Cantidad de Nulos    45428.000000  45430.000000  45430.000000  45431.000000
# Porcentaje de Nulos     99.949396     99.953796     99.953796     99.955997
#
#                        nombre_144    nombre_145    nombre_146    nombre_147  \
# Cantidad de Nulos    45431.000000  45432.000000  45432.000000  45432.000000
# Porcentaje de Nulos     99.955997     99.958197     99.958197     99.958197
#
#                        nombre_148    nombre_149    nombre_150    nombre_151  \
# Cantidad de Nulos    45432.000000  45432.000000  45432.000000  45433.000000
# Porcentaje de Nulos     99.958197     99.958197     99.958197     99.960397
#
#                        nombre_152    nombre_153    nombre_154    nombre_155  \
# Cantidad de Nulos    45435.000000  45435.000000  45435.000000  45435.000000
# Porcentaje de Nulos     99.964797     99.964797     99.964797     99.964797
#
#                        nombre_156    nombre_157    nombre_158    nombre_159  \
# Cantidad de Nulos    45436.000000  45436.000000  45437.000000  45439.000000
# Porcentaje de Nulos     99.966997     99.966997     99.969198     99.973598
#
#                        nombre_160    nombre_161    nombre_162    nombre_163  \
# Cantidad de Nulos    45439.000000  45439.000000  45439.000000  45439.000000
# Porcentaje de Nulos     99.973598     99.973598     99.973598     99.973598
#
#                        nombre_164    nombre_165    nombre_166    nombre_167  \
# Cantidad de Nulos    45439.000000  45440.000000  45440.000000  45441.000000
# Porcentaje de Nulos     99.973598     99.975798     99.975798     99.977998
#
#                        nombre_168    nombre_169    nombre_170    nombre_171  \
# Cantidad de Nulos    45442.000000  45442.000000  45442.000000  45443.000000
# Porcentaje de Nulos     99.980198     99.980198     99.980198     99.982399
#
#                        nombre_172    nombre_173    nombre_174    nombre_175  \
# Cantidad de Nulos    45444.000000  45444.000000  45444.000000  45444.000000
# Porcentaje de Nulos     99.984599     99.984599     99.984599     99.984599
#
#                        nombre_176    nombre_177    nombre_178    nombre_179  \
# Cantidad de Nulos    45444.000000  45444.000000  45444.000000  45444.000000
# Porcentaje de Nulos     99.984599     99.984599     99.984599     99.984599
#
#                        nombre_180    nombre_181    nombre_182    nombre_183  \
# Cantidad de Nulos    45444.000000  45444.000000  45444.000000  45445.000000
# Porcentaje de Nulos     99.984599     99.984599     99.984599     99.986799
#
#                        nombre_184    nombre_185    nombre_186    nombre_187  \
# Cantidad de Nulos    45445.000000  45446.000000  45446.000000  45446.000000
# Porcentaje de Nulos     99.986799     99.988999     99.988999     99.988999
#
#                        nombre_188    nombre_189    nombre_190    nombre_191  \
# Cantidad de Nulos    45446.000000  45446.000000  45446.000000  45446.000000
# Porcentaje de Nulos     99.988999     99.988999     99.988999     99.988999
#
#                        nombre_192    nombre_193    nombre_194    nombre_195  \
# Cantidad de Nulos    45446.000000  45446.000000  45446.000000  45446.000000
# Porcentaje de Nulos     99.988999     99.988999     99.988999     99.988999
#
#                        nombre_196    nombre_197    nombre_198    nombre_199  \
# Cantidad de Nulos    45446.000000  45446.000000  45446.000000  45446.000000
# Porcentaje de Nulos     99.988999     99.988999     99.988999     99.988999
#
#                        nombre_200    nombre_201    nombre_202    nombre_203  \
# Cantidad de Nulos    45446.000000  45446.000000  45446.000000  45446.000000
# Porcentaje de Nulos     99.988999     99.988999     99.988999     99.988999
#
#                        nombre_204    nombre_205    nombre_206    nombre_207  \
# Cantidad de Nulos    45446.000000  45446.000000  45446.000000  45446.000000
# Porcentaje de Nulos     99.988999     99.988999     99.988999     99.988999
#
#                        nombre_208    nombre_209    nombre_210    nombre_211  \
# Cantidad de Nulos    45448.000000  45448.000000  45448.000000  45448.000000
# Porcentaje de Nulos     99.993399     99.993399     99.993399     99.993399
#
#                        nombre_212  nombre_213  nombre_214  nombre_215  \
# Cantidad de Nulos    45448.000000  45449.0000  45449.0000  45449.0000
# Porcentaje de Nulos     99.993399     99.9956     99.9956     99.9956
#
#                      nombre_216  nombre_217  nombre_218  nombre_219  \
# Cantidad de Nulos    45449.0000  45449.0000  45449.0000  45449.0000
# Porcentaje de Nulos     99.9956     99.9956     99.9956     99.9956
#
#                      nombre_220  nombre_221  nombre_222  nombre_223  \
# Cantidad de Nulos    45449.0000  45449.0000  45449.0000  45449.0000
# Porcentaje de Nulos     99.9956     99.9956     99.9956     99.9956
#
#                      nombre_224  nombre_225  nombre_226  nombre_227  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_228  nombre_229  nombre_230  nombre_231  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_232  nombre_233  nombre_234  nombre_235  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_236  nombre_237  nombre_238  nombre_239  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_240  nombre_241  nombre_242  nombre_243  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_244  nombre_245  nombre_246  nombre_247  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_248  nombre_249  nombre_250  nombre_251  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_252  nombre_253  nombre_254  nombre_255  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_256  nombre_257  nombre_258  nombre_259  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_260  nombre_261  nombre_262  nombre_263  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_264  nombre_265  nombre_266  nombre_267  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_268  nombre_269  nombre_270  nombre_271  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_272  nombre_273  nombre_274  nombre_275  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_276  nombre_277  nombre_278  nombre_279  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_280  nombre_281  nombre_282  nombre_283  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_284  nombre_285  nombre_286  nombre_287  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_288  nombre_289  nombre_290  nombre_291  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_292  nombre_293  nombre_294  nombre_295  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_296  nombre_297  nombre_298  nombre_299  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_300  nombre_301  nombre_302  nombre_303  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_304  nombre_305  nombre_306  nombre_307  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_308  nombre_309  nombre_310  nombre_311  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      nombre_312  Nombre_Director   id  budget  \
# Cantidad de Nulos    45450.0000       835.000000  0.0     0.0
# Porcentaje de Nulos     99.9978         1.837143  0.0     0.0
#
#                      original_language    overview  popularity  release_date  \
# Cantidad de Nulos            11.000000  941.000000         0.0           0.0
# Porcentaje de Nulos           0.024202    2.070361         0.0           0.0
#
#                      revenue     runtime     status       tagline  title  \
# Cantidad de Nulos        0.0  246.000000  80.000000  25026.000000    0.0
# Porcentaje de Nulos      0.0    0.541242   0.176014     55.061495    0.0
#
#                      vote_average  vote_count  release_year  return  \
# Cantidad de Nulos             0.0         0.0           0.0     0.0
# Porcentaje de Nulos           0.0         0.0           0.0     0.0
#
#                             BTCid       BTCname  BTCposter_path  \
# Cantidad de Nulos    40954.000000  40954.000000    41497.000000
# Porcentaje de Nulos     90.105828     90.105828       91.300521
#
#                      BTCbackdrop_path     company_0     company_1  \
# Cantidad de Nulos         42185.00000  11817.000000  28414.000000
# Porcentaje de Nulos          92.81424     25.999428     62.515676
#
#                         company_2     company_3     company_4     company_5  \
# Cantidad de Nulos    36382.000000  41108.000000  43057.000000  44010.000000
# Porcentaje de Nulos     80.046644     90.444655     94.732789     96.829553
#
#                        company_6     company_7     company_8     company_9  \
# Cantidad de Nulos    44577.00000  44893.000000  45075.000000  45208.000000
# Porcentaje de Nulos     98.07705     98.772304     99.172735     99.465358
#
#                       company_10    company_11    company_12    company_13  \
# Cantidad de Nulos    45275.00000  45317.000000  45354.000000  45373.000000
# Porcentaje de Nulos     99.61277     99.705177     99.786583     99.828387
#
#                        company_14    company_15    company_16    company_17  \
# Cantidad de Nulos    45389.000000  45398.000000  45419.000000  45426.000000
# Porcentaje de Nulos     99.863589     99.883391     99.929595     99.944996
#
#                        company_18    company_19    company_20    company_21  \
# Cantidad de Nulos    45429.000000  45434.000000  45439.000000  45443.000000
# Porcentaje de Nulos     99.951596     99.962597     99.973598     99.982399
#
#                        company_22    company_23    company_24    company_25  \
# Cantidad de Nulos    45446.000000  45446.000000  45447.000000  45448.000000
# Porcentaje de Nulos     99.988999     99.988999     99.991199     99.993399
#
#                        country_0     country_1     country_2     country_3  \
# Cantidad de Nulos    6219.000000  38404.000000  43287.000000  44758.000000
# Porcentaje de Nulos    13.682867     84.495391     95.238829     98.475281
#
#                         country_4     country_5     country_6     country_7  \
# Cantidad de Nulos    45226.000000  45377.000000  45418.000000  45430.000000
# Porcentaje de Nulos     99.504961     99.837187     99.927394     99.953796
#
#                         country_8     country_9    country_10    country_11  \
# Cantidad de Nulos    45437.000000  45445.000000  45446.000000  45448.000000
# Porcentaje de Nulos     99.969198     99.986799     99.988999     99.993399
#
#                      country_12  country_13  country_14  country_15  \
# Cantidad de Nulos    45449.0000  45449.0000  45449.0000  45450.0000
# Porcentaje de Nulos     99.9956     99.9956     99.9956     99.9978
#
#                      country_16  country_17  country_18  country_19  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      country_20  country_21  country_22  country_23  \
# Cantidad de Nulos    45450.0000  45450.0000  45450.0000  45450.0000
# Porcentaje de Nulos     99.9978     99.9978     99.9978     99.9978
#
#                      country_24   language_0    language_1    language_2  \
# Cantidad de Nulos    45450.0000  3774.000000  37545.000000  42926.000000
# Porcentaje de Nulos     99.9978     8.303448     82.605443     94.444567
#
#                        language_3    language_4    language_5    language_6  \
# Cantidad de Nulos    44630.000000  45182.000000  45360.000000  45422.000000
# Porcentaje de Nulos     98.193659     99.408154     99.799784     99.936195
#
#                        language_7    language_8    language_9   language_10  \
# Cantidad de Nulos    45436.000000  45442.000000  45447.000000  45448.000000
# Porcentaje de Nulos     99.966997     99.980198     99.991199     99.993399
#
#                       language_11  language_12  language_13  language_14  \
# Cantidad de Nulos    45448.000000   45449.0000   45450.0000   45450.0000
# Porcentaje de Nulos     99.993399      99.9956      99.9978      99.9978
#
#                      language_15  language_16  language_17  language_18
# Cantidad de Nulos     45450.0000   45450.0000   45450.0000   45450.0000
# Porcentaje de Nulos      99.9978      99.9978      99.9978      99.9978

# %%
# Convertir columnas con diccionarios a cadenas de texto para evitar errores de tipo unhashable
DF_cleaned = df.applymap(lambda x: str(x) if isinstance(x, dict) else x)

# Valores duplicados
print("\nChequeo de valores duplicados:")
print(f"Cantidad de valores duplicados: {DF_cleaned.duplicated().sum()}")
# Out:
# C:\Users\fede\AppData\Local\Temp\ipykernel_10484\1219452057.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   DF_cleaned = df.applymap(lambda x: str(x) if isinstance(x, dict) else x)
# Chequeo de valores duplicados:
# Cantidad de valores duplicados: 92

# %%
# Valores faltantes
print("\nChequeo de valores faltantes:")
missing_data = df.isnull().sum().reset_index()
missing_data.columns = ['Column', 'Missing Values']
missing_data['Percentage'] = (missing_data['Missing Values'] / df.shape[0]) * 100
print(missing_data)
# Out:
# Chequeo de valores faltantes:
#           Column  Missing Values  Percentage
# 0       nombre_0            2354    5.179204
# 1       nombre_1            3683    8.103232
# 2       nombre_2            4593   10.105388
# 3       nombre_3            5725   12.595982
# 4       nombre_4            8203   18.048008
# ..           ...             ...         ...
# 398  language_14           45450   99.997800
# 399  language_15           45450   99.997800
# 400  language_16           45450   99.997800
# 401  language_17           45450   99.997800
# 402  language_18           45450   99.997800
#
# [403 rows x 3 columns]

# %%
# Valores faltantes
print("\nChequeo de valores faltantes:")
missing_data = df.isnull().sum().reset_index()
missing_data.columns = ['Column', 'Missing Values']
missing_data['Percentage'] = (missing_data['Missing Values'] / df.shape[0]) * 100
print(missing_data)
# Out:
# Chequeo de valores faltantes:
#           Column  Missing Values  Percentage
# 0       nombre_0            2354    5.179204
# 1       nombre_1            3683    8.103232
# 2       nombre_2            4593   10.105388
# 3       nombre_3            5725   12.595982
# 4       nombre_4            8203   18.048008
# ..           ...             ...         ...
# 398  language_14           45450   99.997800
# 399  language_15           45450   99.997800
# 400  language_16           45450   99.997800
# 401  language_17           45450   99.997800
# 402  language_18           45450   99.997800
#
# [403 rows x 3 columns]

# %%
# Tipos de datos
print("\nTipos de datos:")
print(df.dtypes)
# Out:
# Tipos de datos:
# nombre_0       object
# nombre_1       object
# nombre_2       object
# nombre_3       object
# nombre_4       object
#                 ...
# language_14    object
# language_15    object
# language_16    object
# language_17    object
# language_18    object
# Length: 403, dtype: object

# %%
# Convertir columnas con diccionarios a cadenas de texto para evitar errores de tipo unhashable
DF_cleaned = df.applymap(lambda x: str(x) if isinstance(x, dict) else x)

# Análisis de correlaciones
print("\nAnálisis de correlaciones:")
corr_matrix = DF_cleaned.corr()
print(corr_matrix)

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Mapa de calor de correlaciones')
plt.show()
# Out:
# C:\Users\fede\AppData\Local\Temp\ipykernel_10484\428418642.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   DF_cleaned = df.applymap(lambda x: str(x) if isinstance(x, dict) else x)
# Análisis de correlaciones:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 6
#       4 # Análisis de correlaciones
#       5 print("\nAnálisis de correlaciones:")
# ----> 6 corr_matrix = DF_cleaned.corr()
#       7 print(corr_matrix)
#       9 plt.figure(figsize=(12, 8))
#
# File c:\Users\fede\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\fede\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\fede\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\fede\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Tom Hanks'
